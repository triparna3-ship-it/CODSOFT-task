# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\sutra\Downloads\Advanced_Retail_Sales_Dataset_Cleaned_1030rows.csv")

# %%
df.head()
# Out:
#    Sale_ID  Sale_Date Customer_ID    Order_ID Product_ID        Category  \
# 0        1  12/7/2022  CUST-57931  ORD-711097   SKU-1950  Home & Kitchen
# 1        2  04/3/2025  CUST-26226  ORD-334083   SKU-2013           Books
# 2        3  21/2/2025  CUST-99391  ORD-289505   SKU-2688       Groceries
# 3        4  11/8/2024  CUST-86750  ORD-575198   SKU-6924          Beauty
# 4        5  08/7/2024  CUST-47740  ORD-738539   SKU-2199        Clothing
#
#    Quantity  Cost_Price  Selling_Price  Discount_%  Revenue  Profit  \
# 0         3      160.96         187.16          20   449.18  -33.70
# 1         2      100.06         181.75           0   363.50  163.38
# 2         7       61.98          77.67          10   489.32   55.46
# 3         4      201.08         360.18          10  1296.65  492.33
# 4         5      212.45         475.39          25  1782.71  720.46
#
#   Payment_Method     City State Country Sales_Channel  Returned  \
# ...

# %%
df.tail()
# Out:
#       Sale_ID   Sale_Date Customer_ID    Order_ID Product_ID     Category  \
# 1025      707  30/10/2023  CUST-69751  ORD-237733   SKU-9813         Toys
# 1026      922   24/6/2025  CUST-89491  ORD-851197   SKU-5482         Toys
# 1027      305   19/1/2023  CUST-45697  ORD-424433   SKU-8778    Groceries
# 1028      451   19/6/2024  CUST-76913  ORD-516786   SKU-5182  Electronics
# 1029      466   27/9/2022  CUST-54115  ORD-490825   SKU-2082     Clothing
#
#       Quantity  Cost_Price  Selling_Price  Discount_%  Revenue   Profit  \
# 1025         8      352.70         650.48          15  4423.26  1601.66
# 1026         2      110.48         144.93           0   289.86    68.90
# 1027         5      388.73         820.30          10  3691.35  1747.70
# 1028         6      206.15         256.61          10  1385.69   148.79
# 1029         6      359.93         554.46           0  3326.76  1167.18
#
#      Payment_Method         City State Country Sales_Channel  Returned  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sale_ID          1030 non-null   int64
#  1   Sale_Date        1030 non-null   object
#  2   Customer_ID      1030 non-null   object
#  3   Order_ID         1030 non-null   object
#  4   Product_ID       1030 non-null   object
#  5   Category         1018 non-null   object
#  6   Quantity         1030 non-null   int64
#  7   Cost_Price       1030 non-null   float64
#  8   Selling_Price    1030 non-null   float64
#  9   Discount_%       1030 non-null   int64
#  10  Revenue          1030 non-null   float64
#  11  Profit           1030 non-null   float64
#  12  Payment_Method   1015 non-null   object
#  13  City             1023 non-null   object
#  14  State            1030 non-null   object
#  15  Country          1030 non-null   object
# ...

# %%
df.describe(include='all')  #descriptive_statistics
# Out:
#             Sale_ID   Sale_Date Customer_ID    Order_ID Product_ID   Category  \
# count   1030.000000        1030        1030        1030       1030       1018
# unique          NaN         718         994         999        948         14
# top             NaN  30/10/2023  CUST-89491  ORD-424433   SKU-6763  Furniture
# freq            NaN           5           2           2          3        124
# mean     499.974757         NaN         NaN         NaN        NaN        NaN
# std      288.626834         NaN         NaN         NaN        NaN        NaN
# min        1.000000         NaN         NaN         NaN        NaN        NaN
# 25%      251.250000         NaN         NaN         NaN        NaN        NaN
# 50%      498.500000         NaN         NaN         NaN        NaN        NaN
# 75%      748.750000         NaN         NaN         NaN        NaN        NaN
# max     1000.000000         NaN         NaN         NaN        NaN        NaN
#
# ...

# %%
df.describe()
# Out:
#            Sale_ID     Quantity   Cost_Price  Selling_Price   Discount_%  \
# count  1030.000000  1030.000000  1030.000000    1030.000000  1030.000000
# mean    499.974757     8.335922   201.250602     341.627485    19.648544
# std     288.626834    43.584639   111.838801     237.926438    81.977413
# min       1.000000    -3.000000     5.140000    -824.040000   -10.000000
# 25%     251.250000     3.000000   106.462500     168.972500     5.000000
# 50%     498.500000     5.000000   196.360000     327.440000    10.000000
# 75%     748.750000     7.000000   296.347500     493.252500    20.000000
# max    1000.000000   500.000000   399.950000     934.700000   999.000000
#
#            Revenue       Profit  Returned  Customer_Rating
# count  1030.000000  1030.000000       0.0              0.0
# mean   1428.600214   500.753864       NaN              NaN
# std    1213.806858   588.695654       NaN              NaN
# min       5.600000  -266.350000       NaN              NaN
# ...

# %%
df.mean(numeric_only=True) #MEAN
# Out:
# Sale_ID             499.974757
# Quantity              8.335922
# Cost_Price          201.250602
# Selling_Price       341.627485
# Discount_%           19.648544
# Revenue            1428.600214
# Profit              500.753864
# Returned                   NaN
# Customer_Rating            NaN
# dtype: float64

# %%
df.median(numeric_only=True)  #MEDIAN
# Out:
# Sale_ID             498.500
# Quantity              5.000
# Cost_Price          196.360
# Selling_Price       327.440
# Discount_%           10.000
# Revenue            1080.255
# Profit              284.975
# Returned                NaN
# Customer_Rating         NaN
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#     Sale_ID  Quantity  Cost_Price  Selling_Price  Discount_%  Revenue  \
# 0      26.0       7.0      171.18         -27.71         5.0    74.82
# 1      56.0       NaN      196.39          14.63         NaN   161.16
# 2     123.0       NaN      359.93          49.83         NaN   267.22
# 3     133.0       NaN         NaN          71.65         NaN   289.86
# 4     156.0       NaN         NaN          85.22         NaN   298.98
# 5     157.0       NaN         NaN         125.45         NaN   426.53
# 6     210.0       NaN         NaN         133.61         NaN   497.23
# 7     268.0       NaN         NaN         135.21         NaN   511.32
# 8     292.0       NaN         NaN         144.93         NaN   609.04
# 9     305.0       NaN         NaN         157.75         NaN   620.61
# 10    324.0       NaN         NaN         193.94         NaN   719.69
# 11    367.0       NaN         NaN         212.44         NaN   796.65
# ...

# %%
df.std(numeric_only=True) #standard-deviation
# Out:
# Sale_ID             288.626834
# Quantity             43.584639
# Cost_Price          111.838801
# Selling_Price       237.926438
# Discount_%           81.977413
# Revenue            1213.806858
# Profit              588.695654
# Returned                   NaN
# Customer_Rating            NaN
# dtype: float64

# %%
df.var(numeric_only=True)  #variance
# Out:
# Sale_ID            8.330545e+04
# Quantity           1.899621e+03
# Cost_Price         1.250792e+04
# Selling_Price      5.660899e+04
# Discount_%         6.720296e+03
# Revenue            1.473327e+06
# Profit             3.465626e+05
# Returned                    NaN
# Customer_Rating             NaN
# dtype: float64

# %%
df.corr(numeric_only=True)  #correlation_btw_variables
# Out:
#                   Sale_ID  Quantity  Cost_Price  Selling_Price  Discount_%  \
# Sale_ID          1.000000 -0.030040    0.005588       0.026717    0.026566
# Quantity        -0.030040  1.000000   -0.012562      -0.026347   -0.007729
# Cost_Price       0.005588 -0.012562    1.000000       0.812730    0.010195
# Selling_Price    0.026717 -0.026347    0.812730       1.000000    0.000492
# Discount_%       0.026566 -0.007729    0.010195       0.000492    1.000000
# Revenue          0.042062 -0.004301    0.661893       0.625866    0.005902
# Profit           0.037049 -0.006519    0.482280       0.576308   -0.030446
# Returned              NaN       NaN         NaN            NaN         NaN
# Customer_Rating       NaN       NaN         NaN            NaN         NaN
#
#                   Revenue    Profit  Returned  Customer_Rating
# Sale_ID          0.042062  0.037049       NaN              NaN
# Quantity        -0.004301 -0.006519       NaN              NaN
# ...

# %%
plt.scatter(df["Revenue"], df["Profit"])

plt.title("Revenue vs Profit")
plt.xlabel("Revenue")
plt.ylabel("Profit")

plt.show()

# %%
plt.scatter(df["Quantity"], df["Revenue"])

plt.title("Quantity vs Revenue")
plt.xlabel("Quantity")
plt.ylabel("Revenue")

plt.show()

# %%
plt.hist(df["Revenue"], bins=40)
plt.title("Revenue Distribution")
plt.xlabel("Revenue")
plt.ylabel("Frequency")
plt.show()  


plt.hist(df["Profit"], bins=20)
plt.title("Profit Distribution")
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.show()

# %%
numeric_columns = df.select_dtypes(include=['int64','float64']).columns                 #detect_outliers

for col in numeric_columns:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col} : {len(outliers)} Outliers")
# Out:
# Sale_ID : 0 Outliers
# Quantity : 8 Outliers
# Cost_Price : 0 Outliers
# Selling_Price : 11 Outliers
# Discount_% : 14 Outliers
# Revenue : 25 Outliers
# Profit : 59 Outliers
# Returned : 0 Outliers
# Customer_Rating : 0 Outliers

# %%
top = df.nlargest(10, "Revenue")   #top_highest_revenue

top[["Sale_ID", "Revenue"]]
# Out:
#      Sale_ID  Revenue
# 72        73  7103.72
# 672      673  6623.04
# 781      782  6582.82
# 678      679  6295.00
# 280      281  6192.63
# 832      833  5576.24
# 760      761  5549.52
# 775      776  5294.24
# 141      142  5131.97
# 303      304  5083.78

# %%
top=df.nlargest(5,"Profit")    #top_5_profit
top[["Sale_ID", "Profit"]]
# Out:
#      Sale_ID   Profit
# 72        73  3940.28
# 672      673  3598.32
# 678      679  3506.84
# 781      782  3412.74
# 280      281  3342.15

# %%
df["Revenue"].sum()  #total_revenue
# Out:
# 1471458.2200000002

# %%
df["Profit"].sum()   #total_profit
# Out:
# 515776.48

# %%
df["Revenue"].mean()   #avarage_revenue
# Out:
# 1428.600213592233

# %%
df["Quantity"].sum()  #total_quantity_sold
# Out:
# 8586

# %%
df["Category"].value_counts()   #best_sold_catagory
# Out:
# Furniture         124
# Books             123
# Clothing          120
# Groceries         111
# Toys              106
# Electronics       106
# Sports            104
# Home & Kitchen     99
# Beauty             90
# Furnture           10
# Beauty              8
# electronics         6
#  Electronics        6
# HOME & KITCHEN      5
# Name: Category, dtype: int64

# %%
df["Payment_Method"].value_counts()    #best_payment_method
# Out:
# Cash             194
# Bank Transfer    174
# Credit Card      169
# Debit Card       166
# UPI              157
# Wallet           155
# Name: Payment_Method, dtype: int64

# %%
grp_state = df.groupby("State")         #high_revenue_state
total_revenue = grp_state["Revenue"].sum()

print(total_revenue.sort_values(ascending=False))
# Out:
# State
# FL    266305.48
# CA    253467.19
# WA    251595.43
# TX    242400.81
# NY    238954.55
# IL    218734.76
# Name: Revenue, dtype: float64

# %%
grp_city=df.groupby("City")              #high_revenue_city
total_revenue = grp_city["Revenue"].sum()
print(total_revenue.sort_values(ascending=False))
# Out:
# City
# Miami          266049.48
# Los Angeles    251088.51
# Seattle        248766.52
# Houston        241328.11
# New York       236977.61
# Chicago        216862.61
# Name: Revenue, dtype: float64

# %%
summary = df.describe(include="all")

summary.to_csv(
    r"C:\Users\sutra\Downloads\Summary_Statistics.csv"
)

print("Summary statistics saved successfully!")
# Out:
# Summary statistics saved successfully!
