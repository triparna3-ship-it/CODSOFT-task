# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\sutra\Downloads\Advanced_Retail_Sales_Dataset_Cleaned_1030rows.csv")

# %%
df.shape
# Out:
# (1030, 14)

# %%
df.columns
# Out:
# Index(['Sale_ID', 'Sale_Date', 'Customer_ID', 'Order_ID', 'Product_ID',
#        'Quantity', 'Cost_Price', 'Selling_Price', 'Discount_%', 'Revenue',
#        'Profit', 'State', 'Country', 'Sales_Channel'],
#       dtype='object')

# %%
product_details = df[                                           #Extract Product Information
    [ "Product_ID",
      "Selling_Price",] ]

product_details.head()
# Out:
#   Product_ID  Selling_Price
# 0   SKU-1950         187.16
# 1   SKU-2013         181.75
# 2   SKU-2688          77.67
# 3   SKU-6924         360.18
# 4   SKU-2199         475.39

# %%
price = df[                                         #Extract Price Information
    [
        "Product_ID",
        "Cost_Price",
        "Selling_Price",
        "Profit"
    ]
]

price.head()
# Out:
#   Product_ID  Cost_Price  Selling_Price  Profit
# 0   SKU-1950      160.96         187.16  -33.70
# 1   SKU-2013      100.06         181.75  163.38
# 2   SKU-2688       61.98          77.67   55.46
# 3   SKU-6924      201.08         360.18  492.33
# 4   SKU-2199      212.45         475.39  720.46

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 print(
# ----> 2     State.idxmax()
#       3 )
#
# NameError: name 'State' is not defined
