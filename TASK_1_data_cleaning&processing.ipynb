# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\sutra\Downloads\Advanced_Retail_Sales_Dataset_Messy_1030rows_19cols.csv")

# %%
df.head()
# Out:
#    Sale_ID  Sale_Date Customer_ID    Order_ID Product_ID        Category  \
# 0        1  12/7/2022  CUST-57931  ORD-711097   SKU-1950  Home & Kitchen
# 1        2  04/3/2025  CUST-26226  ORD-334083   SKU-2013           Books
# 2        3  21/2/2025  CUST-99391  ORD-289505   SKU-2688       Groceries
# 3        4  11/8/2024  CUST-86750  ORD-575198   SKU-6924          Beauty
# 4        5  08/7/2024  CUST-47740  ORD-738539   SKU-2199        Clothing
#
#    Quantity  Cost_Price  Selling_Price  Discount_%  Revenue  Profit  \
# 0         3      160.96         187.16          20   449.18  -33.70
# 1         2      100.06         181.75           0   363.50  163.38
# 2         7       61.98          77.67          10   489.32   55.46
# 3         4      201.08         360.18          10  1296.65  492.33
# 4         5      212.45         475.39          25  1782.71  720.46
#
#   Payment_Method     City State Country Sales_Channel  Returned  \
# ...

# %%
df.shape
# Out:
# (1030, 19)

# %%
df.isnull().sum() #count missing/null values
# Out:
# Sale_ID               0
# Sale_Date             0
# Customer_ID           0
# Order_ID              0
# Product_ID            0
# Category             12
# Quantity              0
# Cost_Price            0
# Selling_Price         0
# Discount_%            0
# Revenue               0
# Profit                0
# Payment_Method       15
# City                  7
# State                 0
# Country               0
# Sales_Channel         0
# Returned           1030
# Customer_Rating    1030
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 30

# %%
df.dropna(axis=0) #remove null rows
# Out:
#       Sale_ID   Sale_Date Customer_ID    Order_ID Product_ID  Quantity  \
# 0           1   12/7/2022  CUST-57931  ORD-711097   SKU-1950         3
# 1           2   04/3/2025  CUST-26226  ORD-334083   SKU-2013         2
# 2           3   21/2/2025  CUST-99391  ORD-289505   SKU-2688         7
# 3           4   11/8/2024  CUST-86750  ORD-575198   SKU-6924         4
# 4           5   08/7/2024  CUST-47740  ORD-738539   SKU-2199         5
# ...       ...         ...         ...         ...        ...       ...
# 1025      707  30/10/2023  CUST-69751  ORD-237733   SKU-9813         8
# 1026      922   24/6/2025  CUST-89491  ORD-851197   SKU-5482         2
# 1027      305   19/1/2023  CUST-45697  ORD-424433   SKU-8778         5
# 1028      451   19/6/2024  CUST-76913  ORD-516786   SKU-5182         6
# 1029      466   27/9/2022  CUST-54115  ORD-490825   SKU-2082         6
#
#       Cost_Price  Selling_Price  Discount_%  Revenue   Profit State Country  \
# ...

# %%
df.dropna(axis=1) #remove null columns
# Out:
#       Sale_ID   Sale_Date Customer_ID    Order_ID Product_ID  Quantity  \
# 0           1   12/7/2022  CUST-57931  ORD-711097   SKU-1950         3
# 1           2   04/3/2025  CUST-26226  ORD-334083   SKU-2013         2
# 2           3   21/2/2025  CUST-99391  ORD-289505   SKU-2688         7
# 3           4   11/8/2024  CUST-86750  ORD-575198   SKU-6924         4
# 4           5   08/7/2024  CUST-47740  ORD-738539   SKU-2199         5
# ...       ...         ...         ...         ...        ...       ...
# 1025      707  30/10/2023  CUST-69751  ORD-237733   SKU-9813         8
# 1026      922   24/6/2025  CUST-89491  ORD-851197   SKU-5482         2
# 1027      305   19/1/2023  CUST-45697  ORD-424433   SKU-8778         5
# 1028      451   19/6/2024  CUST-76913  ORD-516786   SKU-5182         6
# 1029      466   27/9/2022  CUST-54115  ORD-490825   SKU-2082         6
#
#       Cost_Price  Selling_Price  Discount_%  Revenue   Profit State Country  \
# ...

# %%
df.shape
# Out:
# (1030, 14)

# %%
df.isnull().sum()
# Out:
# Sale_ID          0
# Sale_Date        0
# Customer_ID      0
# Order_ID         0
# Product_ID       0
# Quantity         0
# Cost_Price       0
# Selling_Price    0
# Discount_%       0
# Revenue          0
# Profit           0
# State            0
# Country          0
# Sales_Channel    0
# dtype: int64

# %%
df.dtypes
# Out:
# Sale_ID               int64
# Sale_Date            object
# Customer_ID          object
# Order_ID             object
# Product_ID           object
# Category           category
# Quantity              int64
# Cost_Price          float64
# Selling_Price       float64
# Discount_%            int64
# Revenue             float64
# Profit              float64
# Payment_Method     category
# City               category
# State              category
# Country            category
# Sales_Channel      category
# Returned            float64
# Customer_Rating     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Sale_ID', 'Sale_Date', 'Customer_ID', 'Order_ID', 'Product_ID',
#        'Quantity', 'Cost_Price', 'Selling_Price', 'Discount_%', 'Revenue',
#        'Profit', 'State', 'Country', 'Sales_Channel'],
#       dtype='object')

# %%
import pandas as pd

# Convert repeated text columns to category
#df["Category"] = df["Category"].astype("category")
#df["Payment_Method"] = df["Payment_Method"].astype("category")
#df["City"] = df["City"].astype("category")
df["State"] = df["State"].astype("category")
df["Country"] = df["Country"].astype("category")
df["Sales_Channel"] = df["Sales_Channel"].astype("category")

# %%
# Verify data types
df.dtypes
# Out:
# Sale_ID             int64
# Sale_Date          object
# Customer_ID        object
# Order_ID           object
# Product_ID         object
# Quantity            int64
# Cost_Price        float64
# Selling_Price     float64
# Discount_%          int64
# Revenue           float64
# Profit            float64
# State            category
# Country          category
# Sales_Channel    category
# dtype: object

# %%
df.to_csv(r"C:\Users\sutra\Downloads\Advanced_Retail_Sales_Dataset_Cleaned_1030rows.csv", index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %%
df.shape
# Out:
# (1030, 14)
